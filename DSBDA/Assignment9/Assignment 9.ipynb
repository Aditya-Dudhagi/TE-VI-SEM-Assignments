# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv("Social_Network_Ads.csv")
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
### separate input and output data
### Select features
X = df[['Age','EstimatedSalary']]

# Target variable
y = df['Purchased']

# %%
# Split dataset into traning and testing dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# %%
# Create Logistic Regression model
model = LogisticRegression()

# %%
# Train model
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
LogisticRegression()
# Out:
# LogisticRegression()

# %%
# Predict
y_pred = model.predict(X_test)

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# %%
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[65  3]
#  [ 8 24]]

# %%
# Extract values
TN, FP, FN, TP = cm.ravel()

print("True Positive:", TP)
print("True Negative:", TN)
print("False Positive:", FP)
print("False Negative:", FN)
# Out:
# True Positive: 24
# True Negative: 65
# False Positive: 3
# False Negative: 8

# %%
# Metrics calculation
accuracy = (TP + TN) / (TP + TN + FP + FN)
error_rate = (FP + FN) / (TP + TN + FP + FN)
precision = TP / (TP + FP)
recall = TP / (TP + FN)

print("Accuracy:", accuracy)
print("Error Rate:", error_rate)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.89
# Error Rate: 0.11
# Precision: 0.8888888888888888
# Recall: 0.75

# %% [markdown]
# ## Assignment 9 without using sklearn library

# %%
X_mean = np.mean(X, axis = 0)
X_std = np.std(X, axis =0 )
X = (X - X_mean) / X_std

# %%
intercept = np.ones((X.shape[0], 1))
X = np.hstack((intercept, X))

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def compute_loss(y, h):
    return (-y * np.log(h) - (1 - y) * np.log(1 - h)).mean()

def train(X, y, lr = 0.1, iterations = 1500):
    weights = np.zeros(X.shape[1])

    for i in range(iterations):
        z = np.dot(X, weights)
        h = sigmoid(z)

        gradient = np.dot(X.T, (h -  y)) / y.size
        weights -= lr * gradient

        if i % 100 == 0:
            loss = compute_loss(y, h)
            print(f"Iteration {i}: Loss {loss:.4f}")
            
    return weights

# %%
final_weights = train(X, y)
# Out:
# Iteration 0: Loss 0.6931
# Iteration 100: Loss 0.3861
# Iteration 200: Loss 0.3599
# Iteration 300: Loss 0.3523
# Iteration 400: Loss 0.3492
# Iteration 500: Loss 0.3478
# Iteration 600: Loss 0.3471
# Iteration 700: Loss 0.3468
# Iteration 800: Loss 0.3466
# Iteration 900: Loss 0.3465
# Iteration 1000: Loss 0.3464
# Iteration 1100: Loss 0.3464
# Iteration 1200: Loss 0.3463
# Iteration 1300: Loss 0.3463
# Iteration 1400: Loss 0.3463

# %%
probabilities = sigmoid(np.dot(X, final_weights))

# %%
y_pred = (probabilities >= 0.5).astype(int)

TP = np.sum((y == 1) & (y_pred == 1))
TN = np.sum((y == 0) & (y_pred == 0))
FP = np.sum((y == 0) & (y_pred == 1))
FN = np.sum((y == 1) & (y_pred == 0))


accuracy = (TP + TN)/(TP + TN + FP + FN)
error_rate = 1 - accuracy
precision =  TP / (TP + FP)
recall = TP / (TP + FN)

print(f"Accuracy: {accuracy}\nError Rate: {error_rate} \nPrecision: {precision}\nRecall: {recall}")
# Out:
# Accuracy: 0.845
# Error Rate: 0.15500000000000003
# Precision: 0.8292682926829268
# Recall: 0.7132867132867133
